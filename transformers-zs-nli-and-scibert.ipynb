# %%
# !pip install transformers
#update scikit-learn
# !pip uninstall scikit-learn -y
# !pip install scikit-learn
from transformers import pipeline
# Out:
# Collecting transformers
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 5.2 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 455 kB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 47.2 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 51.2 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 35.2 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.5
# Found existing installation: scikit-learn 1.0.1
# Uninstalling scikit-learn-1.0.1:
#   Successfully uninstalled scikit-learn-1.0.1
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.2 MB)
#      |████████████████████████████████| 23.2 MB 1.7 MB/s
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.0.1

# %%
# this classifier is not working well at all, returns same probabilities for all classes.
#classifier = pipeline("zero-shot-classification",
                      #model="gsarti/scibert-nli")

# %%
# get biomimicry papers
import pandas as pd
url = 'https://raw.githubusercontent.com/nasa-petal/search-engine/main/golden.json'
df = pd.read_json(url, orient='columns')
df.head(10)
# Out:
#         paper  ...                                         title_full
# 0  2103410568  ...  Building a home from foam—túngara frog foam ne...
# 1  2138292607  ...  A nocturnal mammal, the greater mouse-eared ba...
# 2  2005539166  ...  Polarization sensitivity in two species of cut...
# 3  2151557512  ...  Identification and characterization of a multi...
# 4  2160542693  ...  DIFFERENCES IN POLYSACCHARIDE STRUCTURE BETWEE...
# 5  2130285640  ...  Foam nest components of the túngara frog: a co...
# 6  2168114966  ...  The suctorial organ of the Solifugae (Arachnid...
# 7  1589686983  ...  On the Mound of Macrotermes michaelseni as an ...
# 8  2096244860  ...  A Multi-enzyme Cascade of Hemoglobin Proteolys...
# 9  2052657884  ...             The diversity of hydrostatic skeletons
#
# [10 rows x 19 columns]

# %%
# remap level1 labels
'''
df.level1 = df.level1.replace({'physically_assemble/disassemble' : 'physically assembling or disassembling',
                               'protect_from_harm':'protecting',
                               'sense_send_or_process_information':'sensing, sending or processing information',
                               'sense,_send,_or_process_information': 'sensing, sending or processing information',
                               'chemically_modify_or_change_energy_state':'chemically assembling or breaking down',
                               'maintain_structural_integrity':'managing mechanical forces',
                               'attach':'attaching',
                               'move':'movement',
                               'process_resources':'manipulating solids, liquids, gases or energy',
                               'sustain_ecological_community':'sustaining ecological community',
                               'maintain_ecological_community':'sustaining ecological community',
                               'manipulate_solids,_liquids,_gases,_or_energy':'manipulating solids, liquids, gases or energy',
                               'change_size_or_color':''}, regex=True)
'''
df.level1 = df.level1.replace({'physically_assemble/disassemble' : 'physically_assemble_or_disassemble',
                               'sense,_send,_or_process_information': 'sense_send_or_process_information',
                               'maintain_ecological_community':'sustain_ecological_community',
                               'manipulate_solids,_liquids,_gases,_or_energy':'manipulate_solids_liquids_gases_or_energy'}, regex=True)

# %%
# remove rows with no level1 labels, no paper ids, or no titles
df = df[df['level1'] != '[]']
df = df[df['level1'] != "['']"]
df = df[df['paper'] != '']
df = df[df['title'] != '']
df = df[df['title'] != '[]']
df = df[df['title'] != "['']"]
df = df[df['title_full'] != '']
df = df[df['title_full'] != '[]']
df = df[df['title_full'] != "['']"]
df
# Out:
#            paper  ...                                         title_full
# 0     2103410568  ...  Building a home from foam—túngara frog foam ne...
# 1     2138292607  ...  A nocturnal mammal, the greater mouse-eared ba...
# 2     2005539166  ...  Polarization sensitivity in two species of cut...
# 3     2151557512  ...  Identification and characterization of a multi...
# 4     2160542693  ...  DIFFERENCES IN POLYSACCHARIDE STRUCTURE BETWEE...
# ...          ...  ...                                                ...
# 1125  2102365436  ...  Sag-Mediated Modulated Tension in Terebellid T...
# 1126  2145624080  ...  Structural Design and Biomechanics of Friction...
# 1127  1982097444  ...  Dynamics of leg muscle function in tammar wall...
# 1128  2061440509  ...              Bacterial motility: How do pili pull?
# 1129  2130059179  ...                Ultra-fast underwater suction traps
#
# [1058 rows x 19 columns]

# %%
# combine title and abstract
df['title_and_abstract_full'] = (df['title_full'].fillna('') + '. ' + df['abstract_full'].fillna('')).str.strip('. ')
df['word_count'] = df['title_and_abstract_full'].apply(lambda x: len(x.split()))
print('MAX  length title + abstract ==', df["word_count"].max())
print('MEAN length title + abstract ==', df["word_count"].mean())
# Out:
# MAX  length title + abstract == 835
# MEAN length title + abstract == 195.70793950850663

# %%
# convert array strings to actual arrays
from ast import literal_eval
df['level1'] = df['level1'].apply(literal_eval)
df['title'] = df['title'].apply(literal_eval)
df['abstract'] = df['abstract'].apply(literal_eval)

# show unique level1 labels in the dataset
from itertools import chain

unique_lists_in_items = df.level1
set_of_items = set(chain(*unique_lists_in_items))
print(set_of_items)
# Out:
# {'physically_assemble_or_disassemble', 'maintain_structural_integrity', 'sense_send_or_process_information', 'protect_from_harm', 'change_size_or_color', 'move', 'attach', 'sustain_ecological_community', 'process_resources', 'chemically_modify_or_change_energy_state'}

# %%
'''
sequences_to_classify = [{"MAGID":2114147125,"abstract":"Evidence for self-cleaning in gecko setae. A tokay gecko can cling to virtually any surface and support its body mass with a single toe by using the millions of keratinous setae on its toe pads. Each seta branches into hundreds of 200-nm spatulae that make intimate contact with a variety of surface profiles. We showed previously that the combined surface area of billions of spatulae maximizes van der Waals interactions to generate large adhesive and shear forces. Geckos are not known to groom their feet yet retain their stickiness for months between molts. How geckos manage to keep their feet clean while walking about with sticky toes has remained a puzzle until now. Although self-cleaning by water droplets occurs in plant and animal surfaces, no adhesive has been shown to self-clean. In the present study, we demonstrate that gecko setae are a self-cleaning adhesive. Geckos with dirty feet recovered their ability to cling to vertical surfaces after only a few steps. Self-cleaning occurred in arrays of setae isolated from the gecko. Contact mechanical models suggest that self-cleaning occurs by an energetic disequilibrium between the adhesive forces attracting a dirt particle to the substrate and those attracting the same particle to one or more spatulae. We propose that the property of self-cleaning is intrinsic to the setal nanostructure and therefore should be replicable in synthetic adhesive materials in the future."},
                         {"MAGID":2055451617,"abstract":"The plant surface is by default flat, and development away from this default is thought to have some function of evolutionary advantage. Although the functions of many plant epidermal cells have been described, the function of conical epidermal cells, a defining feature of petals in the majority of insect-pollinated flowers, has not. The location and frequency of conical cells have led to speculation that they play a role in attracting animal pollinators. Snapdragon (Antirrhinum) mutants lacking conical cells have been shown to be discriminated against by foraging bumblebees. Here we investigated the extent to which a difference in petal surface structure influences pollinator behavior through touch-based discrimination. To isolate touch-based responses, we used both biomimetic replicas of petal surfaces and isogenic Antirrhinum lines differing only in petal epidermal cell shape. We show that foraging bumblebees are able to discriminate between different surfaces via tactile cues alone. We find that bumblebees use color cues to discriminate against flowers that lack conical cells--but only when flower surfaces are presented at steep angles, making them difficult to manipulate. This facilitation of physical handling is a likely explanation for the prevalence of conical epidermal petal cells in most flowering plants."},
                         {"MAGID":2005631208,"abstract":"In stark contrast to most aggressive predators, Dosidicus gigas (jumbo squids) do not use minerals in their powerful mouthparts known as beaks. Their beaks instead consist of a highly sclerotized chitinous composite with incremental hydration from the tip to the base. We previously reported l-3,4-dihydroxyphenylalanine (dopa)-histidine (dopa-His) as an important covalent cross-link providing mechanical strengthening to the beak material. Here, we present a more complete characterization of the sclerotization chemistry and describe additional cross-links from D. gigas beak. All cross-links presented in this report share common building blocks, a family of di-, tri-, and tetra-histidine-catecholic adducts, that were separated by affinity chromatography and high performance liquid chromatography (HPLC) and identified by tandem mass spectroscopy and proton nuclear magnetic resonance (1H NMR). The data provide additional insights into the unusually high cross-link density found in mature beaks. Furthermore, we propose both a low molecular weight catechol, and peptidyl-dopa, to be sclerotization agents of squid beak. This appears to represent a new strategy for forming hard tissue in animals. The interplay between covalent cross-linking and dehydration on the graded properties of the beaks is discussed."},
                         {"MAGID":156627570,"abstract":"As human activities continue to alter the global nitrogen cycle, the ability to predict the impact of increased nitrogen loading to freshwater systems is becoming more and more important. Nitrogen retention is of particular interest because it is through its combined processes (denitrification, nitrogen sedimentation and uptake by aquatic plants) that local and downstream nitrogen concentrations are reduced. Here, we compare the magnitude of nitrogen retention and its components in wetlands, lakes and rivers. We show that wetlands retain the highest proportion of total nitrogen loading, followed by lakes and then rivers. The differences in the proportion of N retained among systems is explained almost entirely by differences in water discharge. Denitrification is the primary mechanism of nitrogen retention, followed by nitrogen sedimentation and uptake by aquatic plants."},
                         {"MAGID":2076699264,"abstract":"Cooling is a significant end-use of energy globally and a major driver of peak electricity demand. Air conditioning, for example, accounts for nearly fifteen per cent of the primary energy used by buildings in the United States. A passive cooling strategy that cools without any electricity input could therefore have a significant impact on global energy consumption. To achieve cooling one needs to be able to reach and maintain a temperature below that of the ambient air. At night, passive cooling below ambient air temperature has been demonstrated using a technique known as radiative cooling, in which a device exposed to the sky is used to radiate heat to outer space through a transparency window in the atmosphere between 8 and 13¬†micrometres. Peak cooling demand, however, occurs during the daytime. Daytime radiative cooling to a temperature below ambient of a surface under direct sunlight has not been achieved because sky access during the day results in heating of the radiative cooler by the Sun. Here, we experimentally demonstrate radiative cooling to nearly 5¬†degrees Celsius below the ambient air temperature under direct sunlight. Using a thermal photonic approach, we introduce an integrated photonic solar reflector and thermal emitter consisting of seven layers of HfO2 and SiO2 that reflects 97 per cent of incident sunlight while emitting strongly and selectively in the atmospheric transparency window. When exposed to direct sunlight exceeding 850 watts per square metre on a rooftop, the photonic radiative cooler cools to 4.9¬†degrees Celsius below ambient air temperature, and has a cooling power of 40.1 watts per square metre at ambient air temperature. These results demonstrate that a tailored, photonic approach can fundamentally enable new technological possibilities for energy efficiency. Further, the cold darkness of the Universe can be used as a renewable thermodynamic resource, even during the hottest hours of the day."},
                         {"MAGID":1986827150,"abstract":"Autotomy refers to the voluntary shedding of a body part; a renowned example is tail loss among lizards as a response to attempted predation. Although many aspects of lizard tail autotomy have been studied, the detailed morphology and mechanism remains unclear. In the present study, we showed that tail shedding by the Tokay gecko (Gekko gecko) and the associated extracellular matrix (ECM) rupture were independent of proteolysis. Instead, lizard caudal autotomy relied on biological adhesion facilitated by surface microstructures. Results based on bio-imaging techniques demonstrated that the tail of Gekko gecko was pre-severed at distinct sites and that its structural integrity depended on the adhesion between these segments."},
                         {"MAGID":1983825491,"abstract":"Competition among males for access to reproductive opportunities is a central tenet of behavioural biology that has critical implications for studies of mating systems, sexual selection and the evolution of numerous phenotypic traits. Given the expectation that males should compete vigorously for access to females, it may at first seem paradoxical that males in some species cooperate to reproduce, often resulting in the apparent sacrifice of direct fitness by some members of these cooperative partnerships. Because this form of cooperation lies at the interface between natural, sexual and kin selection, studies of the adaptive consequences of male reproductive cooperation may yield important insights into how complex and sometimes conflicting selective pressures shape individual behaviour. Here, we define and review examples of reproductive cooperation among male animals. We take an integrative approach to reviewing the potential causes of maleemale cooperation, including potential adaptive hypotheses, ecological correlates, phylogenetic patterns and physiological mechanisms. The impact of male reproductive cooperation on sexual selection theory is also discussed. We conclude by outlining several important directions for future research, including efforts to improve understanding of the ecological and demographic contexts in which male reproductive cooperation occurs. Collectively, such analyses promise to improve our understanding of multiple fundamental concepts in evolutionary biology. 2013 The Authors. Published on behalf of The Association for the Study of Animal Behaviour by Elsevier Ltd. All rights reserved."}]
'''
candidate_labels = ['Attach', 'Attach permanently', 'Attach temporarily', 'Modify color or camouflage', 'Change structural color', 'Change chemical color or pigmentation', 'Camouflage or mimicry', 'Modify size shape or material properties', 'Change size or shape', 'Change material properties', 'Modify or convert energy', 'Modify or convert electrical energy', 'Modify or convert magnetic energy', 'Modify or convert chemical energy', 'Modify or convert mechanical energy', 'Modify or convert thermal energy', 'Modify or convert light energy', 'Assemble or break down structure', 'Physically assemble structure', 'Break down structure', 'Move on or through solids liquids or gases', 'Passive movement', 'Passively move through or on solids', 'Passively move through or on liquids', 'Passively move through gases', 'Passively move through or on granular media', 'Active movement', 'Actively move through or on solids', 'Actively move through or on liquids', 'Actively move through gases', 'Actively move through or on granular media', 'Protect from living or non-living threats', 'Protect from living threats', 'Protect from animals', 'Protect from plants', 'Protect from fungi', 'Protect from microbes', 'Protect from non-living threats', 'Protect from solids', 'Protect from excess liquids', 'Protect from loss of liquids', 'Protect from gases', 'Protect from wind', 'Protect from temperature', 'Protect from fire', 'Protect from ice', 'Protect from light', 'Protect from chemicals', 'Protect from radiation', 'Manage mechanical forces', 'Manage external forces', 'Manage impact', 'Regulate drag or turbulence', 'Manage stress or strain', 'Prevent buckling', 'Prevent fracture or rupture', 'Manage shear', 'Prevent or allow deformation', 'Prevent degradation', 'Prevent fatigue', 'Control erosion', 'Regulate wear', 'Sustain ecological community', 'Individual benefit', 'Regulate reproduction or growth', 'Self-replicate', 'Maintain homeostasis or equillibrium', 'Group benefit', 'Coordinate by self-organization', 'Cooperate within or between species', 'Compete within or between species', 'Manage environmental disturbances', 'Manage populations or habitats', 'Manage pests or diseases', 'Maintain biodiversity', 'Chemically assemble or break down', 'Chemically assemble', 'Chemically assemble inorganic compounds', 'Chemically assemble organic compounds', 'Self-assemble', 'Chemically break down', 'Chemically break down inorganic compounds', 'Chemically break down organic compounds', 'Sense send or process information', 'Send signals', 'Send light signals in the visible spectrum', 'Send light signals in the non-visible spectrum', 'Send sound signals', 'Send tactile signals', 'Send chemical signals', 'Send vibratory signals', 'Send electrical or magnetic signals', 'Process signals', 'Differentiate signal from noise', 'Convert signals', 'Respond to signals', 'Sense signals or environmental cues', 'Sense light in the visible spectrum', 'Sense light in the non-visible spectrum', 'Sense electricity or magnetism', 'Sense disease in a living system', 'Sense touch and mechanical forces', 'Sense chemicals', 'Sense atmospheric conditions', 'Sense sound or vibrations', 'Sense temperature cues', 'Sense motion', 'Sense spatial awareness or balance or orientation', 'Sense shape and or or pattern', 'Manipulate solids liquids gases or energy', 'Capture resources', 'Capture solids', 'Capture liquids', 'Capture gases', 'Capture energy', 'Absorb and or or filter resources', 'Absorb and or or filter solids', 'Absorb and or or filter liquids', 'Absorb and or or filter gases', 'Store resources', 'Store solids', 'Store liquids', 'Store gases', 'Store energy', 'Distribute or expel resources', 'Distribute or expel solids', 'Distribute or expel liquids', 'Distribute or expel gases', 'Distribute or expel energy', 'Detox or purify']
candidate_labels_leaves = []
candidate_labels_lvl1 = ['physically assembling or disassembling',
                         'protecting',
                         'sensing, sending or processing information',
                         'chemically assembling or breaking down',
                         'managing mechanical forces',
                         'attaching',
                         'movement',
                         'manipulating solids, liquids, gases or energy',
                         'sustaining ecological community']
candidate_labels_lvl1b = ['assembling',
                         'protecting',
                         'signals',
                         'chemical assembly',
                         'structural integrity',
                         'attaching',
                         'movement',
                         'purifying',
                         'ecological community']

#Define the class labels
#this is the list of labels we're currently using
candidate_labels_lvl1c = ['physically_assemble_or_disassemble',
                          'protect_from_harm',
                          'sense_send_or_process_information',
                          'chemically_modify_or_change_energy_state',
                          'maintain_structural_integrity',
                          'attach',
                          'move',
                          'process_resources',
                          'sustain_ecological_community',
                          'change_size_or_color']

# %%
# take 50 papers from each level1 label = 500 samples for labelling.
samples = []
sampling = df
#print(sampling.shape)

for label in candidate_labels_lvl1c:
  docs_with_label = sampling[pd.DataFrame(sampling['level1'].tolist()).isin([label]).any(1).values]
  sample = docs_with_label.head(50) #.sample(n = 3) #[5:7]
  samples.append(sample)
  sampling = sampling.drop(sample.index)
  #print(sampling.shape)
df_samples = pd.concat(samples)
df_samples
# Out:
#            paper  ... word_count
# 0     2103410568  ...        205
# 5     2130285640  ...        254
# 9     2052657884  ...        245
# 26    2039799445  ...        130
# 43    2133743025  ...        202
# ...          ...  ...        ...
# 1005  2128823378  ...        203
# 1007  1996290428  ...        249
# 1040  1675132674  ...        120
# 1086  1986883107  ...        194
# 1093  2149509323  ...        149
#
# [500 rows x 21 columns]

# %%
# create our ground truth matrix D x T where row indexes are the paper MAGIDS, and the columns are the topics. A 1 means the paper had the label in the ground truth data, a 0 means it didn't. 
y_true = []
indexes = []

for idx, sequence in df_samples.iterrows():
  row = []
  indexes.append(sequence['paper'])
  for label in candidate_labels_lvl1c:
    if (label in sequence['level1']):
      row.append(1)
    else:
      row.append(0)
  y_true.append(row)

# add a column to our dataframe to hold our ground truth labels. for the scibert model
df_samples['target_list'] = y_true

df_truth = pd.DataFrame(y_true, index = indexes, columns = candidate_labels_lvl1c)
df_truth
# Out:
#             physically_assemble_or_disassemble  ...  change_size_or_color
# 2103410568                                   1  ...                     0
# 2130285640                                   1  ...                     0
# 2052657884                                   1  ...                     0
# 2039799445                                   1  ...                     1
# 2133743025                                   1  ...                     1
# ...                                        ...  ...                   ...
# 2128823378                                   0  ...                     1
# 1996290428                                   1  ...                     1
# 1675132674                                   0  ...                     1
# 1986883107                                   0  ...                     1
# 2149509323                                   0  ...                     1
#
# [500 rows x 10 columns]

# %%
# SCIBERT supervised model training and validation
# adapted from https://github.com/kyawkhaung/researcharticles/blob/main/classification/3%20Title%20and%20Abstract.ipynb

from transformers import AutoTokenizer, AutoModel
from torch.utils.data import Dataset, DataLoader
import torch
import numpy as np
from IPython.core.debugger import set_trace

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class CustomDataset(Dataset):

    def __init__(self, dataframe, tokenizer, max_len):
        self.tokenizer = tokenizer
        self.data = dataframe
        self.title = dataframe['title_and_abstract_full']
        self.targets = self.data.target_list
        self.max_len = max_len

    def __len__(self):
        return len(self.title)

    def __getitem__(self, index):
        title = str(self.title[index])
        title = " ".join(title.split())

        inputs = self.tokenizer.encode_plus(
            title,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            return_token_type_ids=True,
            truncation=True
        )
        ids = inputs['input_ids']
        mask = inputs['attention_mask']
        token_type_ids = inputs["token_type_ids"]


        return {
            'ids': torch.tensor(ids, dtype=torch.long),
            'mask': torch.tensor(mask, dtype=torch.long),
            'token_type_ids': torch.tensor(token_type_ids, dtype=torch.long),
            'targets': torch.tensor(self.targets[index], dtype=torch.float)
        }

# %%
MAX_LEN = 512 #835 is our max length title + abstract but scibert only allows 512
TRAIN_BATCH_SIZE = 8 # must evenly divide into the training set size (400) #32
VALID_BATCH_SIZE = 4 # must evenly divide into the test set size (100) #32
EPOCHS = 2 #4
LEARNING_RATE = 1e-05
tokenizer = AutoTokenizer.from_pretrained("allenai/scibert_scivocab_uncased")
#tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# Out:
# Downloading:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/223k [00:00<?, ?B/s]

# %%
class SCIBERTClass(torch.nn.Module):
    def __init__(self):
        super(SCIBERTClass, self).__init__()
        self.l1 = AutoModel.from_pretrained('allenai/scibert_scivocab_uncased')
        #self.l1 = AutoModel.from_pretrained('bert-base-uncased')
        self.l2 = torch.nn.Dropout(0.3)
        self.l3 = torch.nn.Linear(768, 10) # 10 for number of classes we want to predict
    
    def forward(self, ids, mask, token_type_ids):
        _, output_1= self.l1(ids, attention_mask = mask, token_type_ids = token_type_ids, return_dict=False)
        output_2 = self.l2(output_1)
        output = self.l3(output_2)
        return output

model = SCIBERTClass()
model.to(device)
# Out:
# Downloading:   0%|          | 0.00/422M [00:00<?, ?B/s]
# Some weights of the model checkpoint at allenai/scibert_scivocab_uncased were not used when initializing BertModel: ['cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# SCIBERTClass(
#   (l1): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(31090, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (l2): Dropout(p=0.3, inplace=False)
#   (l3): Linear(in_features=768, out_features=10, bias=True)
# )

# %%
def loss_fn(outputs, targets):
    return torch.nn.BCEWithLogitsLoss()(outputs, targets)

optimizer = torch.optim.Adam(params =  model.parameters(), lr=LEARNING_RATE)

# %%
val_targets=[]
# stores the predictions on the test set.
val_outputs=[] 

def train_model(start_epochs,  n_epochs, valid_loss_min_input, 
                training_loader, validation_loader, model, 
                optimizer, checkpoint_path, best_model_path):
   
  # initialize tracker for minimum validation loss
  valid_loss_min = valid_loss_min_input 
   
 
  for epoch in range(start_epochs, n_epochs+1):
    train_loss = 0
    valid_loss = 0

    model.train()
    print('############# Epoch {}/{}: Training Start   #############'.format(epoch, n_epochs))
    for batch_idx, data in enumerate(training_loader):
        #print('yyy epoch', batch_idx)
        ids = data['ids'].to(device, dtype = torch.long)
        mask = data['mask'].to(device, dtype = torch.long)
        token_type_ids = data['token_type_ids'].to(device, dtype = torch.long)
        targets = data['targets'].to(device, dtype = torch.float)

        outputs = model(ids, mask, token_type_ids)

        optimizer.zero_grad()
        loss = loss_fn(outputs, targets)
        #if batch_idx%5000==0:
         #   print(f'Epoch: {epoch}, Training Loss:  {loss.item()}')
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #print('before loss data in training', loss.item(), train_loss)
        train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.item() - train_loss))
        #print('after loss data in training', loss.item(), train_loss)
    
    print('############# Epoch {}/{}: Training End     #############'.format(epoch, n_epochs))
    
    print('############# Epoch {}/{}: Validation Start   #############'.format(epoch, n_epochs))
    ######################    
    # validate the model #
    ######################
 
    model.eval()
   
    with torch.no_grad():
      for batch_idx, data in enumerate(validation_loader, 0):
            ids = data['ids'].to(device, dtype = torch.long)
            mask = data['mask'].to(device, dtype = torch.long)
            token_type_ids = data['token_type_ids'].to(device, dtype = torch.long)
            targets = data['targets'].to(device, dtype = torch.float)
            outputs = model(ids, mask, token_type_ids)

            loss = loss_fn(outputs, targets)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.item() - valid_loss))
            if epoch == n_epochs:
              val_targets.extend(targets.cpu().detach().numpy().tolist())
              # store the predictions on the test set for the last EPOCH for each split
              val_outputs.extend(torch.sigmoid(outputs).cpu().detach().numpy().tolist())

      print('############# Epoch {}/{}: Validation End     #############'.format(epoch, n_epochs))
      # calculate average losses
      #print('before cal avg train loss', train_loss)
      train_loss = train_loss/len(training_loader)
      valid_loss = valid_loss/len(validation_loader)
      # print training/validation statistics 
      print('Epoch: {}/{} \tAvgerage Training Loss: {:.6f} \tAverage Validation Loss: {:.6f}'.format(
            epoch,
            n_epochs, 
            train_loss,
            valid_loss
            ))
      
      # create checkpoint variable and add important data
      checkpoint = {
            'epoch': epoch + 1,
            'valid_loss_min': valid_loss,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict()
      }
        
        # save checkpoint
      #save_ckp(checkpoint, False, checkpoint_path, best_model_path)
        
      ## TODO: save the model if validation loss has decreased
      if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).'.format(valid_loss_min,valid_loss)) # Saving model ...
        # save checkpoint as best model
        #save_ckp(checkpoint, True, checkpoint_path, best_model_path)
        valid_loss_min = valid_loss

    print('############# Epoch {}/{}  Done   #############\n'.format(epoch, n_epochs))


  return model

# %%
# Training parameters

train_params = {'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

test_params = {'batch_size': VALID_BATCH_SIZE,
                'shuffle': False,
                'num_workers': 0
                }

# %%
# NOTICE: This cell performs training of the SciBERT model and generates predictions on the test set, and takes a while to complete.

checkpoint_path = None
best_model = None

# K-Fold setup
from sklearn.model_selection import KFold
# CONFIG: reduce n_splits from 5 to 2 to speed up training at the cost of potentially worse performance.
kf = KFold(n_splits=2, shuffle=True, random_state=1)
splits = list(kf.split(df_samples))

i = 1

for split in splits:
  print('############# Split {}/{}  Start   #############\n'.format(i,len(splits)))
  
  # Split data sample into train and test
  df_train = df_samples.iloc[split[0]]
  df_test =  df_samples.iloc[split[1]]
  df_train = df_train.reset_index(drop=True)
  df_test = df_test.reset_index(drop=True)

  training_set = CustomDataset(df_train, tokenizer, MAX_LEN)
  test_set = CustomDataset(df_test, tokenizer, MAX_LEN)

  training_loader = DataLoader(training_set, **train_params)
  test_loader = DataLoader(test_set, **test_params)

  # Train the model on the train set, and generate predictions on the test set.
  trained_model = train_model(1, EPOCHS, np.Inf, training_loader, test_loader, model, 
                      optimizer,checkpoint_path,best_model)
  print('############# Split {}/{}  Done   #############\n'.format(i,len(splits)))
  i += 1

# end SCIBERT supervised model training and validation
# Out:
# ############# Split 1/2  Start   #############
#
# ############# Epoch 1/2: Training Start   #############
# ############# Epoch 1/2: Training End     #############
# ############# Epoch 1/2: Validation Start   #############
# ############# Epoch 1/2: Validation End     #############
# Epoch: 1/2 	Avgerage Training Loss: 0.013373 	Average Validation Loss: 0.006881
# Validation loss decreased (inf --> 0.006881).
# ############# Epoch 1/2  Done   #############
#
# ############# Epoch 2/2: Training Start   #############
# ############# Epoch 2/2: Training End     #############
# ############# Epoch 2/2: Validation Start   #############
# ############# Epoch 2/2: Validation End     #############
# Epoch: 2/2 	Avgerage Training Loss: 0.013066 	Average Validation Loss: 0.006772
# Validation loss decreased (0.006881 --> 0.006772).
# ############# Epoch 2/2  Done   #############
#
# ############# Split 1/2  Done   #############
#
# ############# Split 2/2  Start   #############
#
# ############# Epoch 1/2: Training Start   #############
# ############# Epoch 1/2: Training End     #############
# ############# Epoch 1/2: Validation Start   #############
# ############# Epoch 1/2: Validation End     #############
# Epoch: 1/2 	Avgerage Training Loss: 0.013216 	Average Validation Loss: 0.006224
# Validation loss decreased (inf --> 0.006224).
# ############# Epoch 1/2  Done   #############
#
# ############# Epoch 2/2: Training Start   #############
# ############# Epoch 2/2: Training End     #############
# ############# Epoch 2/2: Validation Start   #############
# ############# Epoch 2/2: Validation End     #############
# Epoch: 2/2 	Avgerage Training Loss: 0.012506 	Average Validation Loss: 0.006037
# Validation loss decreased (0.006224 --> 0.006037).
# ############# Epoch 2/2  Done   #############
#
# ############# Split 2/2  Done   #############

# %%
# instantiate our pretrained zero-shot classifier
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")
# Out:
# Downloading:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
# NOTICE: This cell generates predictions using bart-large-mnli and takes awhile to complete.

# generate scores for each label for each paper in the test set using bart-large-mnli

col_scores = []
indexes = []

i = 1
total_samples = len(df_samples.index)
for idx, sequence in df_samples.iterrows():
  title_sentence = " ".join(sequence['title'])
  abs_sentence = " ".join(sequence['abstract'])
  sentence = title_sentence + " " + abs_sentence
  #sentence = sequence['title_full'] + " " + sequence['abstract_full']
  print('Predicting labels for document ', i, '/', total_samples)
  print(sentence)
  i += 1

  doc_scores = classifier(sentence, candidate_labels_lvl1c, multi_label=True, device=device)
  row = []
  indexes.append(sequence['paper'])
  for label in candidate_labels_lvl1c:
    index = doc_scores['labels'].index(label)
    doc_score = doc_scores['scores'][index]
    row.append(doc_score)
  col_scores.append(row)

df_sys = pd.DataFrame(col_scores, index = indexes, columns = candidate_labels_lvl1c)
df_sys
# Out:
# Predicting labels for document  1 / 500
# building home foam tungara frog foam nest architecture three phase construction process frogs build foam nests floating water face problems over dispersion secretions eggs dangerously exposed air interface nest construction behaviour tungara engystomops pustulosus features may circumvent pairs periodic bursts production egg deposition three discrete phases discernible first characterized bubble raft without approximately linear increase duration mixing events time phase reduce initial precursor materials until critical concentration achieved main building marked start intervals nearly constant final change exponential fashion joining colonial nesting abbreviate presumably exploiting pioneer pair thereby reducing energy material expenditure predators finally deposited centre continuously 1 cm deep free cortex protectively encloses hatched larvae stranded
# Predicting labels for document  2 / 500
# foam nest components tungara frog cocktail proteins conferring physical biological resilience foam nests tungara frog engystomops pustulosus form biocompatible incubation medium eggs sperm resisting considerable environmental microbiological assault shown behaviour attributed cocktail six proteins designated ranaspumins rsn 1 6 predominate fall two discernable classes sequence biophysical properties 2 amphiphilic amino acid unlike hitherto exhibits substantial detergent surfactant activity necessary production yet harmless membranes spermatozoa four 3 lectins three similar fucolectins found teleosts previously identified land vertebrate though carbohydrate binding specificity different sixth structurally proteinase inhibitors cystatin class itself appear exhibit nest potent encoding genes transcribed tissues adult frogs full oviduct glands combinations cystatins roles plants animals defence against microbial colonization insect attack displays novel synergy selected elements innate plus specialized protein comprising unreported strategy protection unattended reproductive stages
# Predicting labels for document  3 / 500
# diversity hydrostatic skeletons remarkably diverse group organisms rely hydrostatic skeleton support movement muscular antagonism amplification force displacement muscle contraction skeletons transmitted rigid skeletal elements instead internal pressure functioning systems depends fact essentially constant volume consist relatively incompressible fluids tissue resulting decrease one dimensions increase another dimension actively passively connective controlling wide array deformations movements changes stiffness created amazing range animals animal structures form anemones polyps extremely wormlike invertebrates tube feet echinoderms mammalian turtle penises burrowing bivalves snails legs spiders addition arms tentacles cephalopods tongue mammals trunk elephant lack fluid filled cavities characterize type normally consider arthropods exoskeleton immediately following molting larval stage insects majority earth
# Predicting labels for document  4 / 500
# microtubule assembly dynamics new insights nanoscale dynamic self assembly behavior microtubule ends characterized spatial resolution light microscopy 200 nm single molecule events lead dynamics less clear recently number vitro studies novel approaches combining laser tweezers microfabricated chambers high tracking bound beads characterize mechanochemical aspects mt nanometer scale addition computational modeling providing framework integrating experimental physically plausible models molecular nanoscale fundamental insights important advancing understanding instability regulated vivo via proteins therapeutic agents mechanical forces
# Predicting labels for document  5 / 500
# microtubule assembly dynamics nanoscale summary background labile nature microtubules critical establishing cellular morphology motility yet molecular basis assembly remains unclear optical tweezers track microtubule polymerization against microfabricated barriers permitting unprecedented spatial resolution find exhibit extensive nanometer scale variability growth rate undergo shortening excursions exceeding five tubulin layers periods overall net indicates guanosine triphosphate gtp cap exist single layer previously length increments over 100 ms time intervals n 16 762 small 0 81 6 60 nm mean standard deviation rarely exceed two dimer lengths indicating occurs almost exclusively via subunit addition rather oligomers recently suggested finally depends weakly load average decreasing 2 fold force increases 7 4 pn 8 conclusions data consistent mechanochemical model spatially extended allows substantial nanoscale still preventing complete catastrophe
# Predicting labels for document  6 / 500
# function sawfish saw summary jawed fishes possess elongated rostrum sense prey manipulate both billfish instance lacks sensory function stun 1 paddlefishes detect orient towards electric fields plankton 2 sturgeons search substrate electroreceptive engulf oral suction show juvenile freshwater sawfish pristis microdon active predators toothed saw simulating capture encountered water column attacked lateral swipes impale compare shovelnose rays share common ray ancestor 3 lack
# Predicting labels for document  7 / 500
# effect abiotic factors foraging strategy orb web spider argiope keyserlingi araneae araneidae environmental conditions light level background contrast temperature might influence spider prey capture success risk predation may advantageous spiders adjust web building behaviour response variation hypothesis examined construction webs decorations conspicuous strands silk hub orb argiope keyserlingi thought one more separate functions attract deter predators advertise oncoming birds preventing damage series experiments relationships weather parameters complementary laboratory exposed two different levels 700 90 lx contrasts black white 20 26 c significantly decorating size influenced dim constructed larger longer alter data availability reduced low temperatures similarly build increase visual signal approaching
# Predicting labels for document  8 / 500
# defensive chemical characterization froth produced cercopid aphrophora cribrata nymphs cercopid aphrophora cribrata cover themselves frothy exudate ingesting sap preferred host plant eastern white pine pinus strobus chemical analyses froth collected revealed array metabolites belonging five classes fatty acid derived alcohols lactones single 1 monoacylglycerol polyol pinitol polyhydroxyalkanoate poly 3 hydroxybutyrate bioassays showed natural cribata synthetic mixture comprised representative compound identified therein repellent ants largely devoid topical irritancy tests cockroaches
# Predicting labels for document  9 / 500
# structural strengthening urchin skeletons collagenous sutural ligaments sea urchin skeletons strengthened flexible collagenous ligaments bind together rigid calcite plates sutures whole without removed bleaching broke lower apically applied forces intact fresh addition three point bending tests excised plate combinations sutural degree strengthening depended position tensile ambital adapical more adoral grow fastest loosest suggesting growth fed growing urchins overall looser unfed looseness visually vibration bleached rang characteristic frequencies indicating sound traveled across tightly fitting damped vibrations loss vibrational energy furthermore held relatively loosely apparently dome skeleton sometimes transforms jointed membrane loosen become
# Predicting labels for document  10 / 500
# comprehensive mapping long range interactions reveals folding principles human genome describe hi c probes three dimensional architecture whole genomes coupling proximity ligation massively parallel sequencing constructed spatial maps human genome resolution 1 megabase confirm presence chromosome territories small gene rich chromosomes identified additional level organization characterized segregation open closed chromatin form two wide compartments scale conformation consistent fractal globule knot free polymer enables maximally dense packing preserving ability easily fold unfold genomic locus distinct more commonly globular equilibrium model power map dynamic conformations
# Predicting labels for document  11 / 500
# microtubule polymerization one step time dynamic assembly microtubules key factor functions cell experiments give insight process molecular level
# Predicting labels for document  12 / 500
# damage fluctuations induce loops optimal transport networks leaf venation pervasive example complex biological network endowing leaves transport system mechanical resilience networks optimized efficiency shown trees loopless dicotyledon large number closed loops functional able fluid event damage vein primary veins inspired two reasons existence high density fluctuations load first case seek optimal presence random averaging over link second optimizes sparsely distributed time sinks find both criteria lead optimum state
# Predicting labels for document  13 / 500
# molecular nanosprings spider capture silk threads spider capture silk natural material outperforms almost synthetic combination strength elasticity structure remarkable still largely unknown proteins crystallized sticky spiral webs orb weaving spiders investigating specifically threads araneus ecribellate major protein flagelliform variety fibroin models molecular supramolecular structures derived amino acid sequences force spectroscopy pulling stretching bulk web molecules fibres revealed rupture peaks sacrificial bonds characteristic self healing biomaterials overall changes exponential both intact strands
# Predicting labels for document  14 / 500
# fluctuations redundancy optimal transport networks structure networks provide optimal transport properties investigated variety contexts different formulations problem recurrently found trees shown contingent assumption stationary flow network time variations fluctuations allowed class structures share hierarchical organization yet contain loops transitions topologies parameters vary examined may strong implications formation natural illustrated example leaf venation
# Predicting labels for document  15 / 500
# vertical jumping galago senegalensis quest obligate mechanical power amplifier bushbabies galago senegalensis renowned phenomenal jumping capacity postulated mechanical power amplification must involved dynamic vertical jumps performed two confirms amplifier inverse dynamics coupled geometric musculo skeletal model elucidate precise nature mechanism powering maximal delivered vastus muscle tendon systems knee extensor comparison external joint powers revealed important transport 65 ankle midfoot via bi articular calf muscles peak output likely implies elastic recoil complex aponeurotic system patterns changes length tension different phases jump found provide strong evidence substantial times 15 argued multiple internal connective tissue sheets attachment structures developed bundles become increasingly stretched preparatory crouching throughout extension phase except last 13 ms push off requirements extensors abruptly falls maximum allowing necessary fast tensed occur
# Predicting labels for document  16 / 500
# cryo em model bullet shaped vesicular stomatitis virus vesicular stomatitis virus vsv bullet shaped rhabdovirus model system negative strand rna viruses direct visualization means cryo electron microscopy show virion contains two nested left handed helices outer helix matrix protein m inner nucleoprotein n hub domain four contact sites link neighboring subunits providing rigidity clamping adjacent turns nucleocapsid side interactions critical form shape structure mutagenesis support description together data mechanism assembly spirals tip become helical trunk both subsequently framed rigidified layer
# Predicting labels for document  17 / 500
# utility saw sawfish cheeks opercles silvery latter bluish reflections snout entirely transparent except tip duskiness extends short way backward sides colors changed little longer silver black lining gill cavity showing bones specimen agrees excellent description type characters mentioned above
# Predicting labels for document  18 / 500
# microtubule catastrophe rescue microtubules long cylindrical polymers composed tubulin subunits cells play essential role architecture motility example give shape serve intracellular transport tracks act key elements important cellular structures axonemes mitotic spindles accomplish varied functions networks dynamic continuously remodeling stochastic length fluctuations ends individual behavior end microtubule termed instability manifests itself periods persistent growth interrupted occasional switching rapid shrinkage called catastrophe back rescue review summarize provide insights mechanisms discuss impact regards dynamics inside
# Predicting labels for document  19 / 500
# structure mechanism mechanical properties pupal attachment greta oto lepidoptera nymphalidae ithomiinae structure mechanism pupal attachment nymphalid greta oto electron microscopy high speed time lapse photography cremaster composed 3 d array hooked setae engage silk fibers spun layers pad lower leaf surface seta comprises shaft terminating strongly curved hook tipped two lateral barbs densely laid built central portion flattening peripherally showed construction fifth instar larvae completed four distinct spinning movements producing random fiber arrangement isotropic strength giving greater flexibility attached series pupa posterior abdomen movement together shape setal hooks thought integral process tensile loading tests failure breakage undergoes gradual destruction releasing found fracture toughness both evolved dual purpose preventing pulled predator weakened wind causes swing
# Predicting labels for document  20 / 500
# sympodial construction fibonacci type leaf rosettes pinguicula moranensis lentibulariaceae background aims leaf rosettes carnivorous pinguicula moranensis follow spiral phyllotaxis approaching fibonacci pattern stalked flowers arise extra axillary sites leaves organization rosette authors aim clarify development flowering species methods formation shown aid scanning electron microscopy key conclusions micrographs show flower terminates article sympodial unit consecutive articles sympodially constructed arranged divergence angles around 1378 homodromy initiation first prophyll inserted obliquely transverse position next floral scape former construction shoots aloe gunnera philodendron product unidirectional confirmed
# Predicting labels for document  21 / 500
# radular teeth models improvement industrial cutting devices limpets gastropoda chitons polyplacophora feed epi endolithic organisms means radula specialized feeding apparatus located mouth cavity owes abrasive capability presence numerous mineralized teeth shape internal structure wearing pattern position distribution hardness elastic properties attempt generate ideas innovation industrial cutting devices remain sharp entire working life mainly fact preferentially occurs surfaces formed tooth shown positioning material characteristics concertedly function minimizing rate wear down maintaining optimal behaviour implementation self sharpening
# Predicting labels for document  22 / 500
# biomaterials recipe squid beak molecular basis biomaterial assembly function provide inspiration materials science designs research explains squid beak transition soft hard identification two families proteins unusual physical properties
# Predicting labels for document  23 / 500
# skin barrier structure function single gel phase model model structure function mammalian skin barrier postulated intercellular lipid stratum corneum exists single coherent lamellar gel phase membrane stabilized composition chain length distributions space virtually boundaries intact unperturbed mainly located lower half crystalline segregation separation may occur desquamation process differs significantly earlier models predicts neither liquid phases nor different hexagonal orthorhombic packing respectively explain measured water permeability absence swelling matrix upon hydration iv simultaneous presence hydrocarbon physiologic temperatures consistent formation according folding norlen 2001 theoretical fully account extraordinary capacity hereafter referred
# Predicting labels for document  24 / 500
# bone density lightweight skeletons birds skeletons birds universally lightweight selection minimizing energy flight functional perspective weight mass animal relative lift generating surfaces key determinant metabolic cost evolution characterized saving adaptations reflected bone shape strengthen stiffen skeleton largely unstudied material properties tissue contribute strength stiffness calculated density cranium humerus femur passerine rodents bats measuring volume helium displacement found average bones densest followed closely increases so both optimization criteria design strong stiff manmade airframes analogy may reflect maximizing data played important roles reconcile conundrum bird appear thin delicate yet just total body terrestrial mammals
# Predicting labels for document  25 / 500
# geographical variation bill size across bird species provides evidence allen rule allen rule proposes appendages endotherms smaller relative body size colder climates order reduce heat loss empirical support mainly derived occasional reports geographical clines extremity individual species interspecific evidence restricted two studies leg proportions seabirds shorebirds phylogenetic comparative analyses 214 bird examine bills significant sites exchange conform comprised eight diverse taxonomic groups toucans african barbets australian parrots estrildid finches canadian galliforms penguins gulls terns across strongly relationships bill length both latitude environmental temperature significantly shorter patterns supporting relation latitudinal altitudinal distribution held
# Predicting labels for document  26 / 500
# morphological variations macrocystis pyrifera falkland islands relation environment season morphological characteristics giant kelp macrocystis pyrifera falkland islands studied december 1985 until march 1987 shallow relatively sheltered coastal zone january deeper offshore field exposed swells seasonal fluctuations lamina wet weight density form pneumatocyst stipe per unit length paralleled frond differences canopies bed probably mainly water movement depth two sites laminae pneumatocysts submersed different shapes canopy forming portions fronds same internodes longer
# Predicting labels for document  27 / 500
# subnanometer atomic force microscopy peptide mineral interactions links clustering competition acceleration catastrophe vitro observations revealed major effects structure growth composition biomineral phases stabilization amorphous precursors acceleration inhibition kinetics alteration impurity signatures deciphering mechanistic sources problematic lack tools resolve molecular structures mineral surfaces atomic force microscopy investigations system designed maximize resolution minimizing contact imaging calcium oxalate monohydrate influence aspartic rich peptides single molecule reveal unique interactions polypeptides lead switching two distinct states interaction positively charged face leads formation peptide film slow adsorption gradual relaxation bound state time dependent include positive feedback step mathematical catastrophe hysteresis characterized rapid fast zero rates small reductions supersaturation negatively clusters impede advancement competition accelerated solute attachment blocking steps implications control pathological mineralization artificial strategies directing crystallization
# Predicting labels for document  28 / 500
# influence fallback foods great ape tooth enamel lucas colleagues recently model fracture deformation concepts describe mammalian tooth enamel may adapted mechanical demands diet al bioes says 30 2008 374 385 review applicability examining existing data food me chanical properties morphology great apes pan pongo gorilla attention paid consumption fallback foods likely play key role influencing ape morphol ogy indeed case consider implications conclusion evolution dentition extinct hominins am j phys anthropol 140 653 660 2009 v c
# Predicting labels for document  29 / 500
# spider web protection visual advertisement role stabilimentum conspicuous white silken adornments stabilimenta commonly found orb webs spiders appear protective devices warn birds presence flight path endowed artificial equivalents tended survive intact early morning period wing unmarked showed high incidence destruction
# Predicting labels for document  30 / 500
# xyloglucan endo transglycosylase xet functions gelatinous layers tension wood fibers poplar glimpse mechanism balancing act trees tension wood specialized tissue deciduous trees functions bending woody stems optimize position space fibers develop one side stem potency shrink opposite creating moment believed gelatinous g cell wall layer containing almost pure cellulose pivotal shrinking analyzing saccharide composition linkage isolated layers poplar found contain matrix components addition xyloglucan abundant endo transglycosylase xet activity hydrolase xth gene products detected developing labeling ccrc m1 monoclonal antibody situ incorporation xxxg sr polyclonal pttxet16 34 respectively indicating incorporated development moreover several transcripts altered generally regulated normal mature evident adjacent 2 propose essential fiber repairing cross links maintaining contact surprisingly persisted years suggesting enzyme death broken process
# Predicting labels for document  31 / 500
# dynamic mechanical properties tissue engineered matrix associated individual chondrocytes success cell tissue engineering approaches restoring biological function facilitated comprehensive fundamental knowledge temporal evolution structure properties newly synthesized matrix quantify dynamic oscillatory mechanical behavior engineered individual chondrocytes cultured vitro 28 days alginate scaffolds magnitude complex modulus phase shift measured culture medium atomic force microscopy afm nanoindentation response imposed deformation amplitude 5 nm frequency f 1 316 hz probe tip geometry 2 m radius sphere 50 square pyramid absence presence growth factors gf insulin factor igf osteogenic protein op conditions nonlinearly dependence approximately f1 ranged 25 kpa theoretical calculations characteristic poroelastic relaxation fp 90 suggested time dependent governed primarily fluid flow poroelasticity rather independent viscoelastic processes solid decreased hydraulic permeability k treatment trend more elastic thought macromolecular biosynthesis density mature organization
# Predicting labels for document  32 / 500
# bamboo inspired optimal design functionally graded hollow cylinders optimal distribution reinforcing fibers stiffening hollow cylindrical composites explored linear elasticity theory spatial vascular bundles wild bamboo nature designed functionally graded material basis design bamboos maximize flexural rigidity optimally regulating radial gradation bundle fact us plant mimetic principle enables realization high stiffness lightweight
# Predicting labels for document  33 / 500
# ecology biology pacific walrus odobenus rosmarus divergens illiger abstractthe distribution physical development pelage dentition feeding behavior reproduction causes mortality population structure pacific walrus odobenus rosmarus divergens studied intermittently 1952 1979 winter animals tend concentrate north central southeastern bering sea ice conditions favorable summer mainly northwestern northeastern chukchi edge northward migrants females young large proportion adult males remains throughout walruses show strong sexual dimorphism 18 longer 45 heavier larger more divergent tusks thicker lighter colored less hairy skin sexually dimorphic otarioid pinnipeds undergo secondary growth beginning time puberty ending full maturity
# Predicting labels for document  34 / 500
# volatile fatty acids methane production relation anaerobic carbohydrate fermentation oryctes nasicornis larvae coleoptera scarabaeidae physico chemical investigations conditions cellulose digestion oryctes nasicornis larvae show intestinal contents constitute reducing alkaline medium mesenteron facultative high ph values whereas proctodeum anaerobiosis strict approaches neutrality cellulase activity detected gut walls products polysaccharide fermentation volatile fatty acids vfa methane identified vfas 3 4 times more concentrated proctodeal dilation acetic acid predominates haemolymph must cross barrier formation takes place exclusively released exterior
# Predicting labels for document  35 / 500
# females floated first bubble rafting snails summary ever mivart asked darwin explain bird half wing biologists challenged extraordinary evolutionary change mechanistically investigate enigmatic origins janthinidae family marine snails raft passively neuston vast oceanic surface habitat constructing floats mucus bubbles first molecular phylogeny confirms janthinids derived epitoniidae wentletraps benthic predators parasites sea anemones corals data support hypothesis rafting evolved via modified epitoniid egg masses rather juvenile droguing reveals sequential modifications float formation function janthinid lineages interpret changes adaptations neustonic existence conclusion supported positive association traits ecological prevalence
# Predicting labels for document  36 / 500
# strength extracellular matrix muscle interface mechanical force generated skeletal muscle cells contraction specialized myofibrillar proteins paper explores contractile sarcomeres individual fiber transferred connective tissue move bones initial key point transfer cell membrane sarcolemma laterally basement extracellular matrix rich laminins integrated collagens transmission tendons connections 1 molecules outside myofiber 2 3 internal cytoplasmic structures cytoskeleton disturbances components complex interactive system adversely affect strength integrity severe diseases aspects crucial linkages reference defects laminin alpha2 integrin alpha7 novel interventions potentially increase reduce damage mentioned highly relevant aging
# Predicting labels for document  37 / 500
# giant siliceous spicules deep sea glass sponge monorhaphis chuni 13 years realizing repair telegraph cable pulled deep sea depth ocean plentifully populated highly diverse fauna flora challenger expedition 1873 1876 treasured rich collection vitreous sponges hexactinellida schulze represent phylogenetically oldest class siliceous phylum porifera eye catching distinct body plan relies filigree skeleton constructed array morphologically determined elements spicules soon german valdivia 1898 1899 describe largest hexactinellid sponge earth 3 m high monorhaphis chuni develops equally bio silica structure giant basal mx10 mm model basic knowledge morphology formation development skeletal achieved formed proteinaceous scaffold composed 27 kda protein mediates lamellae proteins encased number 800 5 10 microm thick concentrically arranged around axial canal matrix almost pure silicon oxide providing unusually optophysical properties superior man waveguides experiments might function vivo nonocular photoreception system addition exceptional mechanical combining stability strength stiffness demosponges hexactinellids synthesize enzymatically via enzyme silicatein suggested insights surely contribute applied utilization exploration material biomedical science
# Predicting labels for document  38 / 500
# flow flapping photosynthesis nereocystis leutkeana functional comparison undulate flat blade morphologies number species macroalagae possess flat strap blade morphology habitats exposed rapidly moving water whereas protected sites wider undulate shape explored functional consequences narrow vs wide morphologies giant bull kelpnereocystis luetkeana focused behavior blades ambient currents breakage photosynthesis flowing flap lower amplitude collapse together more streamlined bundle hence experience drag per area flow velocity if algae current swept ruffled forces sometimes sufficient break stipes self shading remain spread morphological trade off reducing photosynthetic14c hco3 uptake rates decrease slow boundary layer surface across diffusion takes place relatively thick flapping stirs enhances carbon both
# Predicting labels for document  39 / 500
# inhibiting bacterial cooperation evolutionarily robust anti biofilm strategy bacteria commonly form dense biofilms encased extracellular polymeric substances eps extremely tolerant antimicrobials reliance shared may weakness social evolution theory predicts inhibiting traits select against resistance show salmonella cooperative trait whose benefit cells inhibition reduces both cell attachment antimicrobial tolerance compare inhibitor conventional evolutionary experiment rapidly evolves see resistant strain outcompeted susceptible treatment explaining why evolve work suggests targeting viable solution problem
# Predicting labels for document  40 / 500
# self assembly amorphous biophotonic nanostructures phase separation vivid colors animal kingdom created pigments wavelength selective scattering light nanostructures investigate quasi ordered avian feather barbs produce iridescent keratin air found two basic morphologies tortuous channels amorphous packings spheres class nanostructure isotropic pronounced characteristic length scale variation composition local structural correlations lead strong backscattering over narrow range optical frequencies little angle incidence properties play important roles social sexual communication effective birds precisely control development nanoscale structures yet grow hypothesize multiple lineages convergently evolved exploit phase separation kinetic arrest self assemble spongy color producing observed strikingly similar assembled fluid mixtures channel sphere spinodal decomposition nucleation growth respectively unstable locked matrix likely entanglement cross linking supermolecular fibers power assembly robustly realize diverse nanoscopic relatively small physical chemical changes
# Predicting labels for document  41 / 500
# dynamical system plant pattern formation rigorous analysis rigorous mathematical discrete dynamical system modeling plant pattern formation model work physicists douady couder fixed points spiral helical lattices occurring plants frequent occurrence fibonacci sequence number visible spirals explained stability structure bifurcation diagram provide detailed
# Predicting labels for document  42 / 500
# hydrophobins multipurpose proteins class hydrophobins small secreted fungal proteins play role broad range processes growth development filamentous fungi instance involved formation aerial structures attachment hyphae hydrophobic surfaces mechanisms fulfill functions property self assemble hydrophilic interfaces 10 nm thin highly amphipathic film complementation studies shown belong closely group morphogenetic evolved function specific evidence indicates assembly monomeric hydrophobin implicated cell wall underlying mechanism yet clear addition monomers act toxins elicitors
# Predicting labels for document  43 / 500
# dispersal generated sexual selection beetle riding pseudoscorpion several generations decaying tree ficus spp populations pseudoscorpion cordylochernes scorpioides disperse climbing elytra harlequin beetles acrocinus longimanus eclosing fly newly mating oviposition act effective dispersal agents field experiments observations indicate mode exploited males compete remain beetle strategic site inseminating females dispersing whereas just eclosed old trees carried large female biased groups pseudoscorpions captured maiden flight generally single male multivariate morphometric analyses indicated riding larger individuals randomly sampled fighting traits exhibiting greatest potential selection highest phoretic differentials sexual receptivity significantly higher beginning end suggesting occurs confirmed insemination take place small displaced subelytral space rivals contrast laboratory size may confer high success low density conditions characterize addition indicating novel role evolution exaggerated suggests oscillating important maintenance extreme phenotypic variation exhibited species
# Predicting labels for document  44 / 500
# kelp produce blade shapes suited different flow regimes new wrinkle synopsis species macroalgae flat strap blades habitats exposed rapidly flowing water wide ruffled undulate protected sites giant bull kelp nereocystis luetkeana investigate ecomorphological differences n low flow remain spread flutter erratically moving thereby enhancing interception light increasing drag contrast rapid collapse streamlined bundles amplitude reducing both transplant experiments field revealed shape blade plastic trait laboratory growing different subjected tensile forces mimicked hydrodynamic experienced regimes showed change induced mechanical stress growth mapped spatial distribution determine morphologies highest rates occur proximal ends transverse narrow lower if longitudinal edges exceed rate midline ruffles elastic buckling similar across width compliant easily pushed configurations g wavelengths whole twist left right handed helicoidal shapes may enhance movements reduce self shading increase mass exchange surfaces
# Predicting labels for document  45 / 500
# cytokeratins mediate epithelial innate defense antimicrobial properties epithelial cells express antimicrobial proteins response invading pathogens little regarding defense mechanisms healthy conditions cytokeratins innate properties constitutively produce cytoprotective peptides glycine rich c terminal fragments derived human cytokeratin 6a identified bactericidal lysate fractions corneal structural revealed keratin kdamps exhibited coil structures low helical content synthetic analogs showed rapid activity against multiple protected bacterial virulence scrambled peptide specific kdamp somewhat reduced alanine substitutions involved binding permeabilization unaffected charge physiological salt concentration knockdown markedly cell lysates vitro susceptibility murine corneas adherence vivo data function endogenous host infection antimicrobials may serve effective therapeutic agents
# Predicting labels for document  46 / 500
# deployment hagfish slime thread skeins requires transmission mixing forces via mucin strands summary hagfishes benthic marine protovertebrates secrete copious quantities slime threatened originates two component glandular exudate comprised coiled bundles cytoskeletal intermediate filaments thread skeins mucin vesicles holocrine secretion seawater rapid deployment both fibrous components resulting liter dilute involves unraveling fraction second 150 m long ellipsoid bundle 100 longer hypothesized skein requires vigorous hydrodynamic mixing presence whole provide evidence indeed crucial specifically show mixed swell elongate high aspect ratio strands attach transmit forces effect loading tension discovery hagfish mechanism vivo helps explain able trap impressive volumes via viscous entrainment believe interaction shear elongated mucins represents unique biology may lead novel technologies transmitting microscale particles typically immune
# Predicting labels for document  47 / 500
# social behavior nesting cliff swallows gregarious behavior birds may regarded result positive social responses such responses generally always balanced negative social responses the social behavior exhibited bird particular situation may thus regarded reflecting balance two responses the social territorial behavior nesting cliff swallows petrochelidon pyrrhonota one colonial passerine birds studied point view summer 1950 fourteen nesting colonies northwestern wyoming facilities provided jackson hole research station new york logical society financial assistance provided grant society i wish acknowledge gratitude cooperation given james simon personnel station aid arnold petersen paul scott nicholas collias joseph hickey margaret hickey critical reading manuscript the foraging area nesting sites four colonies studied intensively shown map fig 1 colony a largest 130 nests situated beneath series concrete spans jackson lake dam colony b 36 nests subsidiary colony a hundred yards north concrete culvert colony c 91 nests also subsidiary a occupied eaves water tower neighboring buildings village moran colony d 18 nests one mile north others concrete culvert flood plains swallows foraged colonies formed geologically recent recession lake river waters left flat expanses heavy soil covered sedges grasses willow scrub lush wet hay fields timothy blue grass sedge fig 2 behind plains terrain generally rises abruptly benches foothills covered sage brush lodgepole pine intensive observations begun july 1 height laying period four colonies near moran continued end august time local breeding birds left area
# Predicting labels for document  48 / 500
# behavior flow morphologically variable seaweed hedophyllum sessile c ag setchell drag force measured individual specimens hedophyllum sessile variable speed flow tank sheltered localities broad bullate blades experience greater water velocity ones more exposed action waves smooth deeply dissected rearranged resulting decrease effective higher speeds individuals assumed compact shape high current reduced over bladed same habitats chronically strong wave reduction may important survival mechanism calm turbulence induced lack streamlining enhance mixing immediate vicinity plant
# Predicting labels for document  49 / 500
# circumferential spicule growth pericellular silica deposition hexactinellid sponge monorhaphis chuni summary giant basal spicule hexactinellid sponge monorhaphis chuni represents longest natural siliceous structure earth composed concentrically arranged lamellae approximately 10 m thick investigated formation outer cellular level microscopic spectroscopic techniques shown outermost lamella begins association cell clusters surface thickening growing cells release silica controlled pericellular material fuses delimited textured layer depressions 20 30 diameter newly formed initially displays 40 wide structured banded ribbons attains plain final step chemical composition studied energy dispersive x ray spectroscopy staining texas red data nests forming starts direct remain initiate development next
# Predicting labels for document  50 / 500
# magnetic termite mound surfaces oriented suit wind shade conditions termites amitermes meridionalis laurensis construct remarkable meridional magnetic mounds northern australia vary geographically mean orientation manner suggests variation adaptive response local environmental conditions theoretical modelling solar irradiance mound rotation experiments show maintenance eastern face temperature plateau dry season likely physical basis subsequent heat transfer shows habitat wind speed shading affect gradients rate change geographic follows long term across maintained locations
# Predicting labels for document  51 / 500
# identification characterization multidomain hyperthermophilic cellulase archaeal enrichment archaea microorganisms wide range carbon energy sources graham al describe archaeal consortium grow temperatures above 90 c crystalline cellulose source potential applications enzymatic degradation extreme conditions
# Predicting labels for document  52 / 500
# function spiral grain trees spiral grain conduits sap lead root branches uniform distribution indicated paths vessels tracheids proven experimentally means dyed injected base stems taken roots trees receiving water one side collar nevertheless stay green continue growing bark distributes food branch flanks stem experimental interruptions caused cambial zone reorient conduit cells directions bypassing interruption grooves cut surface division growth largely genetic control appear especially needed spheres dry straight grained bend twist more exposed strong wind way offering less resistance likely break bending twisting snow slides down rather breaking main function supplies
# Predicting labels for document  53 / 500
# extreme impact cavitation forces biological hammer strike forces peacock mantis shrimp odontodactylus scyllarus summary mantis shrimp renowned unusual breaking shells brief powerful strikes raptorial appendages extreme speeds underwater cavitation occurs hard shelled prey examine magnitude relative contribution impact forces generated peacock odontodactylus scyllarus surprising finding strike generates two high amplitude force peaks typically 390 480 s apart speed imaging measurements acoustic analyses evident first peak caused limb9s second collapse bubbles limb range 400 1501 n reach 504 despite small size o generate thousands times body weight furthermore average 50 may exceed 280 rapid succession suggests potent combination extraordinarily fracture stomatopod9s hammer fundamentally different typical shell crushing mechanisms fish jaws lobster claws played important yet unexamined role evolution form
# Predicting labels for document  54 / 500
# chemical mediation bacterial surface colonisation secondary metabolites red alga delisea pulchra we investigated effects halogenated furanones red alga delisea pulchra colonisation surfaces marine bacteria bacterial abundance surface pulchra assessed using scanning electron microscopy sem significantly lower surfaces 3 algal species lack furanones there also strong inverse correlation bacterial abundance furanone content previously determined different sections thallus pulchra consistent inhibition bacteria furanones based observations experimentally investigated inhibition marine bacteria furanones initially testing effects crude extract pulchra 50 furanones growth 144 strains bacteria isolated surfaces pulchra nearby rocks alga sargassum vestitum this crude extract strongly inhibit growth bacteria 79 strains grew 50 crude extract 63 grew 500 inhibition growth occur strongly source dependent bacteria isolated rocks least affected strains pulchra as inhibition growth provide adequate explanation inverse relationship levels furanones bacteria abundance pulchra proceeded investigate effects metabolites bacterial characteristics relevant colonisation attachment swarming swimming individual furanones crude extract natural concentrations strongly inhibited bacterial attachment laboratory field in laboratory assays attachment 3 strains isolated rocks much strongly affected 3 isolates pulchra contrast pattern growth inhibition we also tested individual furanones swimming swarming 6 bacterial isolates 3 rocks 3 pulchra used attachment assays at least furanones inhibited swarming swimming concentrations isolates indicating specific effects bacterial characteristics as attachment significant differences responses different isolates furanones we also found ability swarm widespread among surface associated marine bacteria suggesting swarming may ecologically important systems overall found effects furanones bacteria varied among 1 furanones 2 bacterial phenotypes 3 different isolates 4 different sources isolation rocks algae this differential inhibition different bacterial isolates phenotypes furanones well affecting overall bacterial abundance alga strong effects species composition bacterial community alga surface the effects furanones specific bacterial colonisation traits discussed light recent evidence demonstrating furanones interfere bacterial acylated homoserine lactone regulatory systems
# Predicting labels for document  55 / 500
# pyrolobus fumarii gen sp nov represents novel group archaea extending upper temperature limit life 113 degrees c novel irregular coccoid shaped archaeum isolated hydrothermally heated black smoker wall tag site mid atlantic ridge depth 3650 meters grew 90 degrees c 113 optimum 106 ph 4 0 6 5 1 salt 7 organism facultatively aerobic obligate chemolithoautotroph gaining energy h2 oxidation nitrate s2o3 2 low concentrations o2 3 v served electron acceptors yielding nh4 h2s h2o end products respectively growth inhibited acetate pyruvate glucose starch sulfur isolate able form colonies plates 102 grow pressure 25000 kpa 250 bar exponentially growing cultures survived one hour autoclaving 121 gc content 53 mol core lipids consisted glycerol dialkyl tetraethers traces di o phytanyl sn cell composed surface layer tetrameric protein complexes arranged p4 lattice center distance 18 nm 16s rrna sequence belonged pyrodictiaceae dna homology composition metabolism describe genus name pyrolobus fire lobe type species fumarii strain 1a dsm 11204
# Predicting labels for document  56 / 500
# deep sea swimming worms luminescent bombs remotely operated vehicles found seven previously unknown species swimming annelid worms below 1800 meters specimens large bore variety elaborate head appendages addition five pairs ellipsoidal organs homologous branchiae produce brilliant green bioluminescence autotomized genes determine evolutionary relationships cirratuliformia form clade acrocirridae closely two pelagic cirratuliforms represents third invasion realm finding emphasizes wealth discoveries deep demersal habitats
# Predicting labels for document  57 / 500
# diel variation ammonia excretion glutamine levels hydration status two species terrestrial isopods terrestrial isopods suborder oniscidea excrete nitrogen diurnally volatile ammonia loaded animals accumulate nonessential amino acids may constitute major nocturnal pool explored relationship excretion glutamine storage mobilization water balance two sympatric species ligidium lapetum section diplocheta hygric armadillidium vulgare crinocheta xeric capable vapor absorption wva 12 h tissue levels contents measured following field collection dusk dawn both diurnal exceeded four fivefold sevenfold night accumulated somatic tissues body wall data support role potential breakdown 162 mol g 1 exceeds 2 5 over 60 fold serve generate high hemolymph concentrations mathtype translator ams latex tdl tex mtef feaafeart1ev1aqatcvaufebsjuyzl2yd9gzlbvynv2caerbulwbln hiov2dgi1btfmbaexatlxbi9gbaerbd9wdylwzybitldharqqtubsr 4rnchbgeagqivu0je9sqqrpepc0xbbl8f4rqqrffpeea0xe9lq jc9 vqaqpepm0xbba9pwe9q8fs0 yqaqpepae9pg0firpepekkfr0xfr x fr xb9adbaqaaegacigaaiaabeqaamaabaabaagcbagaaiikaiaabg gacaqgubgaaeizaiaabccacaqgobgaaeyaaiaabegacaqgobgaagjb vlaadcfadawgaawcbagaaeotaiaabieadawgaaadbagaag4maaqaba aaleqaaogaaiykaaaa 437a text p nh 3 seen volatilization energetic cost light mean similar indicating diel cycles depletion replenishment occurring
# Predicting labels for document  58 / 500
# biological activities rice allelochemicals momilactone b momilactone b play critical roles rice allelopathy physiological genetical approaches plants secrete momilactones rhizosphere over entire life cycle phytotoxic levels able account majority observed allelopathic activities determined few test plant species determine against nine weed four cultivars inhibited arabidopsis alfalfa lettuce cress timothy barnyard grass colonum crabgrass ryegrass concentrations greater 3 0 m respectively inhibition concentration dependent hand effectiveness koshihikari nipponbare norin 8 sasanishiki weak 300 100 may potential templates development control substances selective inhibitory more importantly allelochemicals provide molecular marker breeding engineering efforts directed increasing activity staple food crop
# Predicting labels for document  59 / 500
# ...
# Predicting labels for document  78 / 500
# comparison ir thermography thermocouple measurement heat loss rabbit pinna temperature pinnae male zealand white rabbits measured infrared thermography ambient temperatures 15 20 25 degrees c average pinna 23 0 28 7 36 2 respectively heat loss total surface area calculated 8 3 4 w preoptic changes affect vasomotor state rabbit cooling approximately 1 degree resulted 26 5 heating 33 finally thermocouple simultaneously vasodilated measurements consistently higher thermographically vasoconstricted lower discrepancy two methods measurement
# Predicting labels for document  79 / 500
# salvinia paradox superhydrophobic surfaces hydrophilic pins air retention water barthlott wiersch bohn der pflanzen rheinische meckenheimer allee 170 53115 bonn germany barthlott th schimmel barczewski walheim weis kaltenmaier institute applied physics center functional nanostructures cfn university karlsruhe karlsruhe institute technology kit 76131 karlsruhe germany institute nanotechnology center functional nanostructures cfn forschungszentrum karlsruhe karlsruhe institute technology kit 76021 karlsruhe germany koch biologie und nanobiotechnologie hochschule landwehr 4 47533 kleve germany
# Predicting labels for document  80 / 500
# viscosin like lipopeptides frog skin bacteria inhibit aspergillus fumigatus batrachochytrium dendrobatidis detected imaging mass spectrometry molecular networking amphibian populations worldwide declined become extinct chytridiomycosis pandemic disease caused fungus batrachochytrium dendrobatidis species survived fungal epidemics previous studies suggested resistance presence cutaneous bacteria producing antifungal metabolites understanding still limited assessed potential compounds against human relevant fungi aspergillus work isolated 201 bacterial strains fifteen samples belonging seven frog collected highlands panama tested fumigatus 29 isolates exhibited activity pseudomonas cichorii showed greatest inhibition visualize distribution identify zone p employed maldi imaging mass spectrometry ims ms molecular networking identified viscosin massetolides f g h furthermore vitro b showing mic values 62 50 g ml 31 25 respectively first cyclic depsipeptides
# Predicting labels for document  81 / 500
# cell cell communication gram negative bacteria over last decade so wealth research established bacteria communicate one another small molecules signals enable individuals population coordinate behaviour case pathogens may include decisions attack host organism form biofilm consequently signalling systems excellent targets development antibacterial therapies review assess gram negative cell communication discuss main approaches developed interfere
# Predicting labels for document  82 / 500
# entrapment bed bugs leaf trichomes inspires microfabrication biomimetic surfaces resurgence bed bug infestations widespread pesticide resistance greatly renewed interest development more sustainable environmentally friendly methods manage bugs historically eastern europe entrapped leaves bean plants destroyed purely physical entrapment microscopic hooked hairs trichomes leaf surfaces scanning electron microscopy videography documented capture mechanism impaling feet tarsi distinct velcro piercing entanglement momentarily holds without sustained struggling trapped impaled several legs unable free themselves specific mechanically vulnerable locations pierced located effective heights orientations despite lack evolutionary association templates microfabricated indistinguishable geometry real polymers material properties similar plant cell walls synthetic snag temporarily hinder locomotion effectively
# Predicting labels for document  83 / 500
# naturally occurring nanoparticles english ivy alternative metal based nanoparticles uv protection over last decade safety concerns arisen metal nanoparticles cosmetics field linked both environmental animal toxicity variety studies perhaps greatest concern involves large amounts tio2 commercial sunscreens alternative potentially hazardous isolated organic english ivy hedera helix potential four criteria 1 ability absorb scatter ultraviolet light 2 mammalian cells 3 biodegradability 4 diffusion skin purified first tested uv protective effects standard spectrophotometric assay next cell hela determined several digestion techniques finally mathematical model developed determine penetrate human indicated more efficient blocking less toxic easily biodegradable limited showed decreased degradable indicating safer data collected great sunscreen agent commonly oxide
# Predicting labels for document  84 / 500
# hot bees empty broodnest cells heating within summary honeybee colonies maintain brood nest temperatures 33 36 c investigated thermoregulation level individual worker behaviour transfer heat workers bees contribute regulation temperature producing sitting motionless caps cells additional newly observed heating strategy enter empty sealed remain periods 45 min individually marked surface maintained thorax t th 32 2 1 0 38 5 mean d n 20 alternating warming cooling one several long duration visits area time entered cell entry 34 42 40 83 higher 9 same bee high values resulted preceding activity comb warm ups just prior 6 inside 7 resting without performing visible work resembles cap appear inactive repeated warmings coolings occur fall below optimum staying still minutes previously bees9 find distinguished body continuous rapid respiratory movements abdomens contrast abdominal pumping discontinuous interrupted pauses simulated controlled conditions causes strong superficial 3 30 times more efficient touch raises adjacent flow detectable three away heated
# Predicting labels for document  85 / 500
# blood flow appendages control heat exchange american alligators small american alligators 200 400 g heated cooled 20 35 c temperature controlled wind tunnel blood flow limbs tail periodically occluded remotely occlusion cuffs appendages rate heating significantly reduced unrestricted cooling affected rather generalized perfusion skin appears primarily responsible differences rates
# Predicting labels for document  86 / 500
# home ranges movement den use long beaked echidnas zaglossus bartoni papua new guinea long beaked echidnas zaglossus endemic guinea largest least studied 3 extant genera monotremes listed endangered world conservation union data regarding natural history critical efforts protect animals detailed studies ecology genus published 2000 2005 captured 22 bartoni crater mountain wildlife management area simbu province papua mean body masses 6 5 kg 1 4 sd n 15 range 2 9 adults 7 juveniles eleven followed via radiotelemetry 12 months home ranges individuals varied size 10 168 ha correlated mass age sex echidna dens commonly located underground burrows individual favored different types den sites burrow length m 8 depth 0 48 42 57 below soil surface never found foraging daylight eggs young pouch lactating april 2002 again generated provide valuable insights biology facilitate conserve populations unusual mammals
# Predicting labels for document  87 / 500
# fighting bacterial fire bacterial fire microbiologywork presented last week annual meeting american society cell biology san francisco suggests applying harmless bacterium products surgical wounds may thwart infections dangerous pathogen staphylococcus aureus major cause hospital acquired physicians previously pitted one against another prevent intestinal genitourinary tracts first attempt friendly microbe infection say experts point mechanism bacterial interference protein secreted prevents getting foothold injured tissue
# Predicting labels for document  88 / 500
# comparative overwintering physiology alaska indiana populations beetle cucujus clavipes fabricius roles antifreeze proteins polyols dehydration diapause beetle cucujus clavipes found north america over broad latitudinal range carolina latitude approximately 35 degrees n tree line brooks alaska 67 30 cold adaptations populations northern indiana 41 45 expected supercooling points temperatures froze freeze avoiding insects significantly lower both produce glycerol concentrations larvae higher 2 0 5 mol l 1 respectively addition antifreeze proteins interestingly autumn same approximate level hemolymph thermal hysteresis indicative protein activity suggesting synthesize similar amounts major difference undergo extreme dehydration winter wherein water content decreases 63 65 body 70 85 g h2o dry mass summer 28 40 68 4 6 fold reductions greatly increase 7 10 nearly 13 c highest ever measured organism concentrated contrast desiccate population undergoes diapause likely additional mean 23 42 certain times cooled 80
# Predicting labels for document  89 / 500
# gamma aminobutyrate defense invertebrate pests gamma aminobutyrate gaba ubiquitous four carbon protein amino acid plants stress induced accumulation documented role contentious opinion article argue wounding herbivory crawling insect larvae causes rapid via disruption cellular compartmentation release acidic vacuolar contents cytosol activity glutamate decarboxylase cytosolic enzyme responsible synthesis ph optimum subsequent ingestion plant defense function directly acting regulated invertebrate neuromuscular junctions enhanced producing capacity reduce pests rapidly deployed local resistance mechanism constitutes first line deterring
# Predicting labels for document  90 / 500
# lactobacillus fermentum rc 14 inhibits staphylococcus aureus infection surgical implants rats staphylococcus aureus common cause community hospital acquired infections moreover clinical impact rise global increase incidence multidrug resistant strains growing prevalence major surgical pressing identify antistaphylococcal agents preventative strategies help management types describes successful probiotic lactobacillus fermentum rc 14 secreted biosurfactant inhibit implant caused l both significantly inhibited infection bacteria adherence implants
# Predicting labels for document  91 / 500
# test whether economy nutrition determines fecal sac ingestion nesting corvids parent birds species eat fecal sacs nestlings two hypotheses explain why parents ingest rather simply remove 1 parental nutrition hypothesis proposes benefits energetically nutritionally ingesting morton 1979 gluck 1988 2 economic disposal postulates incur costs eating waste products cost less gained allowed remain nest hurd al 1991 behavioral data nesting florida scrub jays aphelocoma c coerulescens american crows corvus brachyrhynchos support both production stressed female ate significantly more her mate occasions one adult left immediately sac remained departing likely dispose neither carry
# Predicting labels for document  92 / 500
# exploitation mutualisms mutualisms interspecific cooperative interactions ubiquitously exploited organisms obtain benefits mutualists offer delivering return natural history exploiters relatively little effort yet devoted analysing ecological evolutionary significance mutualism exploitation unitary phenomenon set loosely phenomena may follow mixed strategies pure species individual level derived inflict significant costs implications different forms especially threats pose stability minimally explored studies issue usually framed terms temptation defect generates destabilizing conflict interest partners argue idea fact rather inappropriate interpreting observed several alternative testable ideas persist face
# Predicting labels for document  93 / 500
# respiration buried echidnas tachyglossus aculeatus short beaked echidnas impressive ability submerge completely soil sand remain cryptic long periods poses questions manage respiration cut off free flow gases measured gradient oxygen partial pressure p o2 away snouts buried consumption v five individuals similar conditions two substrates different air filled porosities f theoretical diffusion model indicated alone insufficient account flux meet rates noticed showed periodic movements anterior part body if deliberate effort flush tidal space surrounding nostrils flushing subsequently found temporarily increase levels interstitial around head region more frequent higher burrowing process substrate lower fa conclude supply maintained augmented ventilate airspace surrounds
# Predicting labels for document  94 / 500
# differential response circularly polarized light jewel scarab beetle chrysina gloriosa circularly polarized light rare terrestrial environment cuticular reflections scarab beetles one few natural sources chrysina gloriosa leconte 1854 beetle found montane juniper forests extreme southwestern united states northern mexico camouflaged foliage viewed right polarizing filters exhibit stark black contrast polarization specific changes appearance c hypothesized detect tested phototactic response differential flight orientation toward different stimuli exhibited positive phototaxis b linear equal intensities discrimination unpolarized lights consistent model circular sensitivity quarter wave plate respond differentially woodi horn 1885 close relative reduced reflection may allow perceive communicate conspecifics remain cryptic predators reducing indirect costs communication
# Predicting labels for document  95 / 500
# antifreeze activity antarctic fish glycoprotein synthetic polymer antifreeze glycoproteins afgps proteins isolated sera polar fish species overwintering insects able depress freezing temperature aqueous body fluids water means ligative all previous measurements antifreeze effect performed bulk samples conditions ice nucleation would catalysed participate impurities giving limited indeterminate degrees undercooling we report first measurements homogeneous spontaneous ice nucleation rates deeply 233 k solutions afgp polyvinyl pyrrolidone pvp polymer finds use cryoprotectant antifreeze activity said3 derive sorption afgp molecules active growth sites ice crystals preventing normal growth inducing unusual crystal habits we performed experiments inhibition ice crystal growth solutions containing afgp pvp standardized conditions find homogeneous nucleation crystallization rates sensitive low concentrations substances afgp remarkably effective inhibiting ice crystal growth
# Predicting labels for document  96 / 500
# actuation systems plants prototypes bioinspired devices plants evolved multitude mechanisms actuate organ movement osmotic influx efflux water living cells cause rapid organs predetermined direction even dead tissue actuated swelling drying plant cell walls deformation controlled different levels hierarchy geometrical constraints micrometre level g shape size wall polymer composition nanoscale cellulose fibril orientation paper reviews highlights research field attention paid systems activated without metabolism design principles may particularly useful biomimetic translation active technical composites moving devices
# Predicting labels for document  97 / 500
# biofouling lessons nature biofouling generally undesirable applications overview medical marine industrial fields susceptible fouling presented two types include organism colonization inorganic living particles nature offers solutions control physical chemical mechanisms examples low drag adhesion wettability water repellency attraction microtexture grooming sloughing miscellaneous behaviours secretions survey flora fauna taken order discover antifouling methods mimicked engineering currently employed ranging coatings cleaning techniques presumably incorporate combination controls
# Predicting labels for document  98 / 500
# hemozoin oil versus water quinolines inhibit heme crystallization malaria parasite work focused mechanism formation inhibition hemozoin review evidence lipids diverse parasites implications lipid site drug targeting leukocytes generate toxic radical metabolites may alter immune function reduce deformability uninfected erythrocytes

# %%
# generate Average Precision scores for each topic
from sklearn.metrics import (average_precision_score, precision_recall_curve, PrecisionRecallDisplay)
import matplotlib.pyplot as plt

# %%
# bart-large-mnli scores

y_true = np.array(y_true)
y_true_t = y_true.transpose()
y_scores = np.array(col_scores)
y_scores_t = y_scores.transpose()
ap_by_topic = []
pr_by_topic = []

for idx, topic in enumerate(y_true_t):
   ap = average_precision_score(topic, y_scores_t[idx])
   precision, recall, _ = precision_recall_curve(topic, y_scores_t[idx])
   ap_by_topic.append(ap)
   pr_by_topic.append([precision, recall])

tmp = [ap_by_topic]
df_ap_by_topic = pd.DataFrame(tmp, columns = candidate_labels_lvl1c)

# Generate MAP and gMAP scores
map = sum(ap_by_topic) / len(ap_by_topic)

multiply = 1
values = ap_by_topic
n = len(values)

for i in values:
    multiply = (multiply)*(i)

gmap = (multiply)**(1/n)

print('bart-large-mnli evaluation results')
print(' MAP Score: ', map)
print('gMAP Score: ', gmap)
print('Average Precision by Class')
df_ap_by_topic

# %%
# SciBERT scores

y_true_sb = np.array(val_targets)
y_true_sb_t = y_true_sb.transpose()
y_scores_scibert = np.array(val_outputs)
y_scores_scibert_t = y_scores_scibert.transpose()
ap_sb_by_topic = []
pr_sb_by_topic = []

for idx, topic in enumerate(y_true_sb_t):
   ap_scibert = average_precision_score(topic, y_scores_scibert_t[idx])
   precision_sb, recall_sb, _ = precision_recall_curve(topic, y_scores_scibert_t[idx])
   ap_sb_by_topic.append(ap_scibert)
   pr_sb_by_topic.append([precision_sb, recall_sb])

tmp2 = [ap_sb_by_topic]
df_ap_sb_by_topic = pd.DataFrame(tmp2, columns = candidate_labels_lvl1c)

# Generate MAP and gMAP scores
map_sb = sum(ap_sb_by_topic) / len(ap_sb_by_topic)

multiply = 1
values = ap_sb_by_topic
n = len(values)

for i in values:
    multiply = (multiply)*(i)

gmap_sb = (multiply)**(1/n)

print('scibert evaluation results')
print(' MAP Score: ', map_sb)
print('gMAP Score: ', gmap_sb)
print('Average Precision by Class')
df_ap_sb_by_topic

# %%
# PR curves for each topic - bart-large-mnli

i = 0

for pr in pr_by_topic:
  disp = PrecisionRecallDisplay(precision=pr[0], recall=pr[1])
  disp.plot(name=candidate_labels_lvl1c[i])
  i += 1

plt.show()

# %%
# PR curves for each topic - scibert
i = 0
for pr in pr_sb_by_topic:
  disp = PrecisionRecallDisplay(precision=pr[0], recall=pr[1])
  disp.plot(name=candidate_labels_lvl1c[i])
  i += 1

plt.show()

# %%
# bart-large-mnli: show the top k documents for each topic label. total_relevant are the total # of relevant documents for that label in the ground truth.

df_tmp = df_sys

topk = []
k = 10

for label in candidate_labels_lvl1c:
  df_tmp = df_tmp.sort_values(by=[label], ascending=False)
  i = 1
  total_rel = df_truth[label].sum()
  for idx, sequence in df_tmp.iterrows():
    title = df.loc[df['paper'] == idx,'title_full'].values[0]
    #title_sentence = " ".join(title)
    rel = df_truth.loc[idx,label]
    row = [label, idx, title, sequence[label], rel, total_rel]
    topk.append(row)
    i += 1
    if (i > k):
      break;
df_topk_by_topic = pd.DataFrame(topk, columns = ['label','MAGID','title','score','truly_relevant?', 'total_relevant'])
pd.set_option('display.max_rows', 300)
pd.set_option("max_colwidth", 150)
df_topk_by_topic
